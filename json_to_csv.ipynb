# %%
import pandas as pd

# Đọc file JSON
df = pd.read_json('dataset.json')

df
# Out:
#                                                     url  \
# 0     https://baochinhphu.vn/ban-hanh-vi-tri-viec-la...
# 1     https://baochinhphu.vn/thiet-ke-co-che-chinh-s...
# 2     https://baochinhphu.vn/bo-truong-bo-giao-thong...
# 3     https://baochinhphu.vn/bo-chinh-tri-ban-bi-thu...
# 4     https://baochinhphu.vn/quang-nam-quyet-tam-hoa...
# ...                                                 ...
# 5809  https://baochinhphu.vn/chu-tich-nuoc-du-chuong...
# 5810  https://baochinhphu.vn/thu-tuong-pham-minh-chi...
# 5811  https://baochinhphu.vn/thu-tuong-tham-trung-ta...
# 5812  https://baochinhphu.vn/viet-nam-la-mot-tam-guo...
# 5813  https://baochinhphu.vn/dang-xa-hoi-hungary-luo...
#
#                                                   title      publish_date  \
# 0     Ban hành vị trí việc làm của đại biểu Quốc hội...  06/09/2024 16:44
# 1     Thiết kế cơ chế, chính sách bảo vệ môi trường ...  06/09/2024 16:40
# ...

# %%
# Lưu thành file CSV
df.to_csv('output.csv', index=False, encoding='utf-8-sig')

print("✅ Đã lưu thành công thành file combined.csv")
# Out:
# ✅ Đã lưu thành công thành file combined.csv
